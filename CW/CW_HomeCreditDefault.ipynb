# %% [markdown]
# <a href="https://colab.research.google.com/github/mborkhat/AISem3/blob/master/CW/CW_HomeCreditDefault.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#pip install kaggle

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
import os
os.environ['KAGGLE_CONFIG_DIR'] = "/content/gdrive/My Drive/Kaggle"
# /content/gdrive/My Drive/Kaggle is the path where kaggle.json is present in the Google Drive

# %%
pwd
# Out:
# '/content'

# %%
cd /content/gdrive/My Drive/Kaggle
# Out:
# /content/gdrive/My Drive/Kaggle

# %%
# !kaggle competitions download -c home-credit-default-risk
# Out:
# ...
# 100% 271M/271M [00:04<00:00, 82.2MB/s]
#
# bureau.csv.zip: Skipping, found more recently modified local copy (use --force to force download)
# ...
#  86% 31.0M/36.1M [00:00<00:00, 34.2MB/s]
# 100% 36.1M/36.1M [00:00<00:00, 46.4MB/s]
# ...
#  89% 97.0M/109M [00:01<00:00, 50.4MB/s]
# 100% 109M/109M [00:01<00:00, 61.0MB/s]
# credit_card_balance.csv.zip: Skipping, found more recently modified local copy (use --force to force download)
# sample_submission.csv: Skipping, found more recently modified local copy (use --force to force download)
# bureau_balance.csv.zip: Skipping, found more recently modified local copy (use --force to force download)
# application_test.csv.zip: Skipping, found more recently modified local copy (use --force to force download)
# ...
#  83% 63.0M/76.3M [00:01<00:00, 54.8MB/s]
# 100% 76.3M/76.3M [00:01<00:00, 68.5MB/s]
# ...
#   0% 0.00/36.5k [00:00<?, ?B/s]
# 100% 36.5k/36.5k [00:00<00:00, 5.28MB/s]

# %%
# !unzip \*.zip  && rm *.zip
# Out:
# Archive:  bureau_balance.csv.zip
#   End-of-central-directory signature not found.  Either this file is not
#   a zipfile, or it constitutes one disk of a multi-part archive.  In the
#   latter case the central directory and zipfile comment will be found on
#   the last disk(s) of this archive.
# Archive:  bureau.csv.zip
#   End-of-central-directory signature not found.  Either this file is not
#   a zipfile, or it constitutes one disk of a multi-part archive.  In the
#   latter case the central directory and zipfile comment will be found on
#   the last disk(s) of this archive.
# Archive:  credit_card_balance.csv.zip
#   End-of-central-directory signature not found.  Either this file is not
#   a zipfile, or it constitutes one disk of a multi-part archive.  In the
#   latter case the central directory and zipfile comment will be found on
#   the last disk(s) of this archive.
# Archive:  application_test.csv.zip
# ...

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
application_train=pd.read_csv("application_train.csv")

# %%
application_train.isnull().sum().sort_values(ascending=False)
# Out:
# COMMONAREA_MEDI                214865
# COMMONAREA_AVG                 214865
# COMMONAREA_MODE                214865
# NONLIVINGAPARTMENTS_MODE       213514
# NONLIVINGAPARTMENTS_MEDI       213514
#                                 ...
# REG_CITY_NOT_LIVE_CITY              0
# LIVE_REGION_NOT_WORK_REGION         0
# REG_REGION_NOT_WORK_REGION          0
# HOUR_APPR_PROCESS_START             0
# SK_ID_CURR                          0
# Length: 122, dtype: int64

# %%
number_col = application_train.select_dtypes('number')
#int_col = application_train.select_dtypes('int')
object_col = application_train.select_dtypes('object')

# %%
for f in number_col:
   application_train[f] = application_train[f].fillna(application_train[f].mean())

# %%
for f in object_col:
   application_train[f] = application_train[f].fillna(application_train[f].mode())

# %%
application_train.head()
# Out:
#    SK_ID_CURR  TARGET  ... AMT_REQ_CREDIT_BUREAU_QRT AMT_REQ_CREDIT_BUREAU_YEAR
# 0      100002       1  ...                  0.000000                   1.000000
# 1      100003       0  ...                  0.000000                   0.000000
# 2      100004       0  ...                  0.000000                   0.000000
# 3      100006       0  ...                  0.265474                   1.899974
# 4      100007       0  ...                  0.000000                   0.000000
#
# [5 rows x 122 columns]

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
for i in object_col:
    X[i]=le.fit_transform(X[i])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /usr/local/lib/python3.6/dist-packages/sklearn/preprocessing/_label.py in _encode(values, uniques, encode, check_unknown)
#     111         try:
# --> 112             res = _encode_python(values, uniques, encode)
#     113         except TypeError:
#
# /usr/local/lib/python3.6/dist-packages/sklearn/preprocessing/_label.py in _encode_python(values, uniques, encode)
#      59     if uniques is None:
# ---> 60         uniques = sorted(set(values))
#      61         uniques = np.array(uniques, dtype=values.dtype)
#
# TypeError: '<' not supported between instances of 'str' and 'float'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-32-e172568b3e38> in <module>()
#       2 le=LabelEncoder()
# ...

# %%
X=application_train.drop(['TARGET','SK_ID_CURR'],axis=1)
y=application_train['TARGET']

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
for i in object_col:
    X[i]=le.fit_transform(X[i])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /usr/local/lib/python3.6/dist-packages/sklearn/preprocessing/_label.py in _encode(values, uniques, encode, check_unknown)
#     111         try:
# --> 112             res = _encode_python(values, uniques, encode)
#     113         except TypeError:
#
# /usr/local/lib/python3.6/dist-packages/sklearn/preprocessing/_label.py in _encode_python(values, uniques, encode)
#      59     if uniques is None:
# ---> 60         uniques = sorted(set(values))
#      61         uniques = np.array(uniques, dtype=values.dtype)
#
# TypeError: '<' not supported between instances of 'str' and 'float'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-34-e172568b3e38> in <module>()
#       2 le=LabelEncoder()
# ...

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.1,random_state=42)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report
clf=LogisticRegression(max_iter=1000)
clf.fit(X_train,y_train)
y_pred=clf.predict(X_test)
print(classification_report(y_pred,y_test))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-28-a3be1f445eae> in <module>()
#       2 from sklearn.metrics import classification_report
#       3 clf=LogisticRegression(max_iter=1000)
# ----> 4 clf.fit(X_train,y_train)
#       5 y_pred=clf.predict(X_test)
#       6 print(classification_report(y_pred,y_test))
#
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/_logistic.py in fit(self, X, y, sample_weight)
#    1525
#    1526         X, y = check_X_y(X, y, accept_sparse='csr', dtype=_dtype, order="C",
# -> 1527                          accept_large_sparse=solver != 'liblinear')
#    1528         check_classification_targets(y)
#    1529         self.classes_ = np.unique(y)
#
# ...

# %%
application_train.head()
# Out:
#    SK_ID_CURR  TARGET  ... AMT_REQ_CREDIT_BUREAU_QRT AMT_REQ_CREDIT_BUREAU_YEAR
# 0      100002       1  ...                       0.0                        1.0
# 1      100003       0  ...                       0.0                        0.0
# 2      100004       0  ...                       0.0                        0.0
# 3      100006       0  ...                       NaN                        NaN
# 4      100007       0  ...                       0.0                        0.0
#
# [5 rows x 122 columns]

# %%
bureau = pd.read_csv("bureau.csv")
bureau_balance= pd.read_csv("bureau_balance.csv")
credit_card_balance = pd.read_csv("credit_card_balance.csv")
installments_payments = pd.read_csv("installments_payments.csv")
previous_application = pd.read_csv("previous_application.csv")
POS_CASH_balance = pd.read_csv("POS_CASH_balance.csv")

# %%
application_test = pd.read_csv("application_test.csv")

# %%
bureau.head()
# Out:
#    SK_ID_CURR  SK_ID_BUREAU  ... DAYS_CREDIT_UPDATE AMT_ANNUITY
# 0      215354       5714462  ...               -131         NaN
# 1      215354       5714463  ...                -20         NaN
# 2      215354       5714464  ...                -16         NaN
# 3      215354       5714465  ...                -16         NaN
# 4      215354       5714466  ...                -21         NaN
#
# [5 rows x 17 columns]

# %%
bureau_balance.head()
# Out:
#    SK_ID_BUREAU  MONTHS_BALANCE STATUS
# 0       5715448               0      C
# 1       5715448              -1      C
# 2       5715448              -2      C
# 3       5715448              -3      C
# 4       5715448              -4      C

# %%
credit_card_balance.head()
# Out:
#    SK_ID_PREV  SK_ID_CURR  ...  SK_DPD  SK_DPD_DEF
# 0     2562384      378907  ...       0           0
# 1     2582071      363914  ...       0           0
# 2     1740877      371185  ...       0           0
# 3     1389973      337855  ...       0           0
# 4     1891521      126868  ...       0           0
#
# [5 rows x 23 columns]

# %%
installments_payments.head()
# Out:
#    SK_ID_PREV  SK_ID_CURR  ...  AMT_INSTALMENT  AMT_PAYMENT
# 0     1054186      161674  ...        6948.360     6948.360
# 1     1330831      151639  ...        1716.525     1716.525
# 2     2085231      193053  ...       25425.000    25425.000
# 3     2452527      199697  ...       24350.130    24350.130
# 4     2714724      167756  ...        2165.040     2160.585
#
# [5 rows x 8 columns]

# %%
previous_application.head()
# Out:
#    SK_ID_PREV  SK_ID_CURR  ... DAYS_TERMINATION  NFLAG_INSURED_ON_APPROVAL
# 0     2030495      271877  ...            -37.0                        0.0
# 1     2802425      108129  ...         365243.0                        1.0
# 2     2523466      122040  ...         365243.0                        1.0
# 3     2819243      176158  ...           -177.0                        1.0
# 4     1784265      202054  ...              NaN                        NaN
#
# [5 rows x 37 columns]

# %%
POS_CASH_balance.head()
# Out:
#    SK_ID_PREV  SK_ID_CURR  ...  SK_DPD  SK_DPD_DEF
# 0     1803195      182943  ...       0           0
# 1     1715348      367990  ...       0           0
# 2     1784872      397406  ...       0           0
# 3     1903291      269225  ...       0           0
# 4     2341044      334279  ...       0           0
#
# [5 rows x 8 columns]

# %%
application_train.shape, application_test.shape, previous_application.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-6a46cee8bb26> in <module>()
# ----> 1 application_train.shape, application_test.shape, previous_application.shape
#
# NameError: name 'application_train' is not defined

# %%
#train=pd.merge(application_train,previous_application)

# %%
#train=pd.merge(application_train,Bureau_merged)

# %%
#Bureau_merged=pd.merge(bureau,bureau_balance)

# %%
#train=pd.merge(application_train,Bureau_merged)

# %%
#bureau_mean = bureau.drop(columns = ['SK_ID_BUREAU']).groupby('SK_ID_CURR', as_index = False).agg(['mean']).reset_index()
#bureau_mean.head()
# Out:
#   SK_ID_CURR  DAYS_CREDIT  ... DAYS_CREDIT_UPDATE  AMT_ANNUITY
#                      mean  ...               mean         mean
# 0     100001  -735.000000  ...         -93.142857  3545.357143
# 1     100002  -874.000000  ...        -499.875000     0.000000
# 2     100003 -1400.750000  ...        -816.000000          NaN
# 3     100004  -867.000000  ...        -532.000000          NaN
# 4     100005  -190.666667  ...         -54.333333  1420.500000
#
# [5 rows x 13 columns]

# %%
#columns = ['SK_ID_CURR']

#for var in bureau_mean.columns.levels[0]:
#      if var != 'SK_ID_CURR':
#        for stat in bureau_mean.columns.levels[1][:-1]:
#            columns.append('bureau_%s_%s' % (var, stat))

# %%
#bureau_mean.columns = columns
#bureau_mean.head()
# Out:
#    SK_ID_CURR  ...  bureau_AMT_ANNUITY_mean
# 0      100001  ...              3545.357143
# 1      100002  ...                 0.000000
# 2      100003  ...                      NaN
# 3      100004  ...                      NaN
# 4      100005  ...              1420.500000
#
# [5 rows x 13 columns]

# %%
#bureau_mean.shape
# Out:
# (305811, 13)
